# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers

# %%
# %load_ext tensorboard
# %rm -rf ./logs/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
IMG_CHANNELS = 3
IMG_ROWS =32
IMG_COLS = 32

# %%
BATCH_SIZE = 128
EPOCHS = 20
CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = tf.keras.optimizers.RMSprop()

# %%
def build(input_shape, classes):
    model = models.Sequential()
    model.add(layers.Convolution2D(32, (3,3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.25))
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(classes, activation='softmax'))
    return model

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

y_train = tf.keras.utils.to_categorical(y_train, CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, CLASSES)

model=build((IMG_ROWS, IMG_COLS, IMG_CHANNELS), CLASSES)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3686912
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,692,938
# Trainable params: 3,692,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=OPTIM,
	metrics=['accuracy'])
 
model.fit(x_train, y_train, batch_size=BATCH_SIZE,
	epochs=EPOCHS, validation_split=VALIDATION_SPLIT, 
	verbose=VERBOSE) 
score = model.evaluate(x_test, y_test,
                     batch_size=BATCH_SIZE, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/20
# 40000/40000 [==============================] - 25s 620us/sample - loss: 1.7066 - accuracy: 0.3935 - val_loss: 1.3797 - val_accuracy: 0.5201
# Epoch 2/20
# 40000/40000 [==============================] - 25s 614us/sample - loss: 1.3687 - accuracy: 0.5175 - val_loss: 1.4836 - val_accuracy: 0.4816
# Epoch 3/20
# 40000/40000 [==============================] - 26s 642us/sample - loss: 1.2445 - accuracy: 0.5632 - val_loss: 1.2007 - val_accuracy: 0.5870
# Epoch 4/20
# 40000/40000 [==============================] - 25s 637us/sample - loss: 1.1542 - accuracy: 0.5973 - val_loss: 1.1480 - val_accuracy: 0.5998
# Epoch 5/20
# 40000/40000 [==============================] - 25s 622us/sample - loss: 1.0832 - accuracy: 0.6215 - val_loss: 1.1646 - val_accuracy: 0.5901
# Epoch 6/20
# 40000/40000 [==============================] - 25s 617us/sample - loss: 1.0253 - accuracy: 0.6423 - val_loss: 1.0831 - val_accuracy: 0.6249
# Epoch 7/20
# 40000/40000 [==============================] - 26s 661us/sample - loss: 0.9686 - accuracy: 0.6619 - val_loss: 1.0855 - val_accuracy: 0.6181
# Epoch 8/20
# 40000/40000 [==============================] - 25s 637us/sample - loss: 0.9183 - accuracy: 0.6805 - val_loss: 1.0748 - val_accuracy: 0.6310
# Epoch 9/20
# 40000/40000 [==============================] - 26s 648us/sample - loss: 0.8754 - accuracy: 0.6952 - val_loss: 1.0416 - val_accuracy: 0.6480
# Epoch 10/20
# 40000/40000 [==============================] - 26s 659us/sample - loss: 0.8402 - accuracy: 0.7069 - val_loss: 1.0259 - val_accuracy: 0.6582
# Epoch 11/20
# 40000/40000 [==============================] - 27s 669us/sample - loss: 0.7974 - accuracy: 0.7232 - val_loss: 1.0679 - val_accuracy: 0.6438
# Epoch 12/20
# 40000/40000 [==============================] - 27s 663us/sample - loss: 0.7688 - accuracy: 0.7333 - val_loss: 1.0642 - val_accuracy: 0.6506
# Epoch 13/20
# 40000/40000 [==============================] - 27s 676us/sample - loss: 0.7378 - accuracy: 0.7471 - val_loss: 1.0478 - val_accuracy: 0.6543
# Epoch 14/20
# 40000/40000 [==============================] - 27s 679us/sample - loss: 0.7079 - accuracy: 0.7573 - val_loss: 1.0706 - val_accuracy: 0.6573
# Epoch 15/20
# 40000/40000 [==============================] - 28s 703us/sample - loss: 0.6750 - accuracy: 0.7692 - val_loss: 1.0700 - val_accuracy: 0.6633
# Epoch 16/20
# 40000/40000 [==============================] - 28s 702us/sample - loss: 0.6559 - accuracy: 0.7761 - val_loss: 1.0800 - val_accuracy: 0.6692
# Epoch 17/20
# 40000/40000 [==============================] - 28s 711us/sample - loss: 0.6288 - accuracy: 0.7841 - val_loss: 1.0642 - val_accuracy: 0.6741
# Epoch 18/20
# 40000/40000 [==============================] - 29s 725us/sample - loss: 0.6026 - accuracy: 0.7894 - val_loss: 1.1551 - val_accuracy: 0.6505
# Epoch 19/20
# 40000/40000 [==============================] - 31s 780us/sample - loss: 0.5880 - accuracy: 0.7988 - val_loss: 1.0618 - val_accuracy: 0.6664
# Epoch 20/20
# 40000/40000 [==============================] - 29s 719us/sample - loss: 0.5584 - accuracy: 0.8076 - val_loss: 1.0274 - val_accuracy: 0.6821
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
#
# Test score: 1.015275330543518
# Test accuracy: 0.6805
