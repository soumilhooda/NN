# %%
def build_model():
    model = models.Sequential()

    #block number 1
    model.add(layers.Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.2))

    #block number 2
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    #block number 3
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.4))

    model.add(layers.Flatten())
    model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

    return model

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

EPOCHS = 50
NUM_CLASSES = 10

# %%
def load_data():
    (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    mean = np.mean(x_train, axis=(0,1,2,3))
    std = np.std(x_train, axis=(0,1,2,3))
    x_train = (x_train-mean)/(std+1e-7)
    x_test = (x_test-mean)/(std+1e-7)

    y_train = tf.keras.utils.to_categorical(y_train, NUM_CLASSES)
    y_test = tf.keras.utils.to_categorical(y_test, NUM_CLASSES)

    return x_train, y_train, x_test, y_test

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
model = build_model()
model.compile(loss='sparse_categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])

batch_size=64
model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCHS, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 145s 3ms/sample - loss: 1.7814 - accuracy: 0.4804 - val_loss: 1.8781 - val_accuracy: 0.4520
# Epoch 2/50
# 50000/50000 [==============================] - 1138s 23ms/sample - loss: 1.1656 - accuracy: 0.6444 - val_loss: 1.1709 - val_accuracy: 0.6195
# Epoch 3/50
# 50000/50000 [==============================] - 138s 3ms/sample - loss: 0.9480 - accuracy: 0.7010 - val_loss: 0.9366 - val_accuracy: 0.6952
# Epoch 4/50
# 50000/50000 [==============================] - 145s 3ms/sample - loss: 0.8043 - accuracy: 0.7383 - val_loss: 0.8388 - val_accuracy: 0.7150
# Epoch 5/50
# 50000/50000 [==============================] - 149s 3ms/sample - loss: 0.7055 - accuracy: 0.7607 - val_loss: 0.7770 - val_accuracy: 0.7285
# Epoch 6/50
# 50000/50000 [==============================] - 172s 3ms/sample - loss: 0.6291 - accuracy: 0.7881 - val_loss: 0.7059 - val_accuracy: 0.7557
# Epoch 7/50
# 50000/50000 [==============================] - 185s 4ms/sample - loss: 0.5765 - accuracy: 0.8006 - val_loss: 0.6636 - val_accuracy: 0.7744
# Epoch 8/50
# 50000/50000 [==============================] - 188s 4ms/sample - loss: 0.5332 - accuracy: 0.8161 - val_loss: 0.6141 - val_accuracy: 0.7959
# Epoch 9/50
# 50000/50000 [==============================] - 183s 4ms/sample - loss: 0.4997 - accuracy: 0.8264 - val_loss: 0.6014 - val_accuracy: 0.7962
# Epoch 10/50
# 50000/50000 [==============================] - 184s 4ms/sample - loss: 0.4724 - accuracy: 0.8374 - val_loss: 0.7020 - val_accuracy: 0.7561
# Epoch 11/50
# 50000/50000 [==============================] - 188s 4ms/sample - loss: 0.4452 - accuracy: 0.8443 - val_loss: 0.5411 - val_accuracy: 0.8164
# Epoch 12/50
# 50000/50000 [==============================] - 186s 4ms/sample - loss: 0.4230 - accuracy: 0.8535 - val_loss: 0.5787 - val_accuracy: 0.8128
# Epoch 13/50
# 50000/50000 [==============================] - 188s 4ms/sample - loss: 0.3994 - accuracy: 0.8616 - val_loss: 0.6309 - val_accuracy: 0.7888
# Epoch 14/50
# 50000/50000 [==============================] - 190s 4ms/sample - loss: 0.3784 - accuracy: 0.8684 - val_loss: 0.5596 - val_accuracy: 0.8174
# Epoch 15/50
# 50000/50000 [==============================] - 191s 4ms/sample - loss: 0.3654 - accuracy: 0.8738 - val_loss: 0.5380 - val_accuracy: 0.8261
# Epoch 16/50
# 50000/50000 [==============================] - 194s 4ms/sample - loss: 0.3512 - accuracy: 0.8765 - val_loss: 0.5751 - val_accuracy: 0.8159
# Epoch 17/50
# 50000/50000 [==============================] - 190s 4ms/sample - loss: 0.3354 - accuracy: 0.8826 - val_loss: 0.5201 - val_accuracy: 0.8289
# Epoch 18/50
# 50000/50000 [==============================] - 190s 4ms/sample - loss: 0.3245 - accuracy: 0.8860 - val_loss: 0.5913 - val_accuracy: 0.8093
# Epoch 19/50
# 50000/50000 [==============================] - 189s 4ms/sample - loss: 0.3162 - accuracy: 0.8885 - val_loss: 0.7083 - val_accuracy: 0.7901
# Epoch 20/50
# 50000/50000 [==============================] - 188s 4ms/sample - loss: 0.3048 - accuracy: 0.8921 - val_loss: 0.5219 - val_accuracy: 0.8352
# Epoch 21/50
# 50000/50000 [==============================] - 185s 4ms/sample - loss: 0.2973 - accuracy: 0.8923 - val_loss: 0.6432 - val_accuracy: 0.8036
# Epoch 22/50
# 50000/50000 [==============================] - 186s 4ms/sample - loss: 0.2871 - accuracy: 0.8981 - val_loss: 0.5293 - val_accuracy: 0.8320
# Epoch 23/50
# 50000/50000 [==============================] - 188s 4ms/sample - loss: 0.2766 - accuracy: 0.9026 - val_loss: 0.5660 - val_accuracy: 0.8250
# Epoch 24/50
# 50000/50000 [==============================] - 186s 4ms/sample - loss: 0.2645 - accuracy: 0.9063 - val_loss: 0.5117 - val_accuracy: 0.8414
# Epoch 25/50
# 50000/50000 [==============================] - 187s 4ms/sample - loss: 0.2576 - accuracy: 0.9069 - val_loss: 0.5648 - val_accuracy: 0.8270
# Epoch 26/50
# 50000/50000 [==============================] - 184s 4ms/sample - loss: 0.2553 - accuracy: 0.9092 - val_loss: 0.5276 - val_accuracy: 0.8396
# Epoch 27/50
# 50000/50000 [==============================] - 183s 4ms/sample - loss: 0.2460 - accuracy: 0.9130 - val_loss: 0.5329 - val_accuracy: 0.8395
# Epoch 28/50
# 50000/50000 [==============================] - 181s 4ms/sample - loss: 0.2374 - accuracy: 0.9150 - val_loss: 0.6921 - val_accuracy: 0.8109
# Epoch 29/50
# 50000/50000 [==============================] - 179s 4ms/sample - loss: 0.2372 - accuracy: 0.9142 - val_loss: 0.5224 - val_accuracy: 0.8364
# Epoch 30/50
# 50000/50000 [==============================] - 182s 4ms/sample - loss: 0.2312 - accuracy: 0.9172 - val_loss: 0.5851 - val_accuracy: 0.8275
# Epoch 31/50
# 50000/50000 [==============================] - 185s 4ms/sample - loss: 0.2265 - accuracy: 0.9192 - val_loss: 0.5688 - val_accuracy: 0.8330
# Epoch 32/50
# 50000/50000 [==============================] - 183s 4ms/sample - loss: 0.2255 - accuracy: 0.9204 - val_loss: 0.5106 - val_accuracy: 0.8553
# Epoch 33/50
# 50000/50000 [==============================] - 184s 4ms/sample - loss: 0.2178 - accuracy: 0.9228 - val_loss: 0.5372 - val_accuracy: 0.8431
# Epoch 34/50
# 50000/50000 [==============================] - 181s 4ms/sample - loss: 0.2134 - accuracy: 0.9242 - val_loss: 0.5167 - val_accuracy: 0.8496
# Epoch 35/50
# 50000/50000 [==============================] - 183s 4ms/sample - loss: 0.2085 - accuracy: 0.9255 - val_loss: 0.5252 - val_accuracy: 0.8474
# Epoch 36/50
# 50000/50000 [==============================] - 181s 4ms/sample - loss: 0.2007 - accuracy: 0.9268 - val_loss: 0.4969 - val_accuracy: 0.8586
# Epoch 37/50
# 50000/50000 [==============================] - 192s 4ms/sample - loss: 0.2002 - accuracy: 0.9291 - val_loss: 0.4908 - val_accuracy: 0.8603
# Epoch 38/50
# 50000/50000 [==============================] - 188s 4ms/sample - loss: 0.1992 - accuracy: 0.9287 - val_loss: 0.5461 - val_accuracy: 0.8442
# Epoch 39/50
# 50000/50000 [==============================] - 187s 4ms/sample - loss: 0.1942 - accuracy: 0.9299 - val_loss: 0.5776 - val_accuracy: 0.8344
# Epoch 40/50
# 50000/50000 [==============================] - 172s 3ms/sample - loss: 0.1888 - accuracy: 0.9332 - val_loss: 0.5164 - val_accuracy: 0.8531
# Epoch 41/50
# 50000/50000 [==============================] - 177s 4ms/sample - loss: 0.1880 - accuracy: 0.9324 - val_loss: 0.5092 - val_accuracy: 0.8507
# Epoch 42/50
# 50000/50000 [==============================] - 183s 4ms/sample - loss: 0.1810 - accuracy: 0.9342 - val_loss: 0.5421 - val_accuracy: 0.8529
# Epoch 43/50
# 50000/50000 [==============================] - 187s 4ms/sample - loss: 0.1846 - accuracy: 0.9344 - val_loss: 0.5741 - val_accuracy: 0.8384
# Epoch 44/50
# 50000/50000 [==============================] - 184s 4ms/sample - loss: 0.1814 - accuracy: 0.9359 - val_loss: 0.5178 - val_accuracy: 0.8540
# Epoch 45/50
# 50000/50000 [==============================] - 197s 4ms/sample - loss: 0.1695 - accuracy: 0.9388 - val_loss: 0.5984 - val_accuracy: 0.8402
# Epoch 46/50
# 50000/50000 [==============================] - 210s 4ms/sample - loss: 0.1756 - accuracy: 0.9379 - val_loss: 0.5775 - val_accuracy: 0.8414
# Epoch 47/50
# 50000/50000 [==============================] - 197s 4ms/sample - loss: 0.1684 - accuracy: 0.9395 - val_loss: 0.5106 - val_accuracy: 0.8525
# Epoch 48/50
# 50000/50000 [==============================] - 201s 4ms/sample - loss: 0.1695 - accuracy: 0.9394 - val_loss: 0.5415 - val_accuracy: 0.8489
# Epoch 49/50
# 50000/50000 [==============================] - 198s 4ms/sample - loss: 0.1629 - accuracy: 0.9414 - val_loss: 0.5419 - val_accuracy: 0.8503
# Epoch 50/50
# 50000/50000 [==============================] - 199s 4ms/sample - loss: 0.1698 - accuracy: 0.9395 - val_loss: 0.5377 - val_accuracy: 0.8511
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
#
# Test score: 0.5376823892593384
# Test accuracy: 0.8511
